# %% [markdown]
# # torchvision.models.resnet18を用いたファインチューニングによる学習とGradCAMによる注視領域の可視化

# %% [markdown]
# ### import

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import time
from copy import deepcopy

# %%
from data_loader import train_loader
from data_loader import train_size
from data_loader import test_loader
from data_loader import test_size
from models.resnet import resnet

# %% [markdown]
# ### device config

# %%
CUDA_LAUNCH_BLOCKING=1

# %%
use_gpu = torch.cuda.is_available()

# %%
device = torch.device("cuda:0" if use_gpu else "cpu")

# %%
print(use_gpu)
# Out:
# True

# %% [markdown]
# ### show samples

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# 訓練データをランダムに取得
dataiter = iter(train_loader)
images, labels = dataiter.next()

# 画像の表示
imshow(torchvision.utils.make_grid(images))
# ラベルの表示
print(' '.join('%5s' % labels[labels[j]] for j in range(10)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(2) tensor(1) tensor(2) tensor(2) tensor(2) tensor(2) tensor(2) tensor(2) tensor(2) tensor(2)

# %% [markdown]
# ### define model, parameter, optimizer, loss function

# %%
resnet = resnet.to(device)
learning_ratio = 1e-4
epochs = 2
optimizer = torch.optim.Adam(resnet.parameters(), lr=learning_ratio, weight_decay=1e-4)
loss_func = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ### Training the model (fine tuning)

# %% [markdown]
# ↓ prepare result container

# %%
elapsed_times = []
loss_transition_holder = []
accracy_transition_holder = []

# %% [markdown]
# ↓ run iteration

# %%
start_time = time.time()

for epoch in range(epochs):

    running_loss = 0.0
    total = 0
    correct = 0
    for i, data in enumerate(train_loader):
        inputs, labels = data
        labels -= 1  # なぜかinputsがImageFolderによって1,2でラベル付けされたらしい。0-indexedにする。
        
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = resnet(inputs)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # statistics
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

        if i % 100 == 99:    # print every 100 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 100))
            print("elapsed time: %.1f s" % (time.time()-start_time))
            
            accuracy = correct / total * 100
            
            # record
            elapsed_times.append(time.time()-start_time)
            loss_transition_holder.append(running_loss)
            accracy_transition_holder.append(accuracy)
            
            # init
            running_loss = 0.0
            total = 0
            correct = 0


elapsed_time = time.time()-start_time
print('Finished Training. Elapsed time: ', elapsed_time)
# Out:
# [1,   100] loss: 0.086
# elapsed time: 95.5 s
# [1,   200] loss: 0.019
# elapsed time: 190.8 s
# [1,   300] loss: 0.003
# elapsed time: 284.2 s
# [1,   400] loss: 0.004
# elapsed time: 378.6 s
# [1,   500] loss: 0.004
# elapsed time: 472.6 s
# [1,   600] loss: 0.009
# elapsed time: 567.5 s
# [1,   700] loss: 0.002
# elapsed time: 662.4 s
# [1,   800] loss: 0.001
# elapsed time: 757.5 s
# [1,   900] loss: 0.001
# elapsed time: 852.3 s
# [1,  1000] loss: 0.000
# elapsed time: 947.4 s
# [1,  1100] loss: 0.000
# elapsed time: 1043.5 s
# [1,  1200] loss: 0.000
# elapsed time: 1139.3 s
# [1,  1300] loss: 0.000
# elapsed time: 1234.4 s
# [1,  1400] loss: 0.000
# elapsed time: 1330.4 s
# [1,  1500] loss: 0.000
# elapsed time: 1425.5 s
# [1,  1600] loss: 0.000
# elapsed time: 1521.7 s
# [1,  1700] loss: 0.000
# elapsed time: 1617.4 s
# [1,  1800] loss: 0.000
# elapsed time: 1712.7 s
# [1,  1900] loss: 0.000
# elapsed time: 1809.1 s
# [1,  2000] loss: 0.000
# elapsed time: 1905.1 s
# [1,  2100] loss: 0.000
# elapsed time: 2002.5 s
# [1,  2200] loss: 0.000
# elapsed time: 2100.0 s
# [1,  2300] loss: 0.000
# elapsed time: 2196.2 s
# [1,  2400] loss: 0.000
# elapsed time: 2293.0 s
# [1,  2500] loss: 0.000
# elapsed time: 2389.0 s
# [1,  2600] loss: 0.000
# elapsed time: 2485.6 s
# [2,   100] loss: 0.000
# elapsed time: 2672.5 s
# [2,   200] loss: 0.000
# elapsed time: 2767.7 s
# [2,   300] loss: 0.000
# elapsed time: 2862.2 s
# [2,   400] loss: 0.000
# elapsed time: 2959.5 s
# [2,   500] loss: 0.000
# elapsed time: 3059.9 s
# [2,   600] loss: 0.000
# elapsed time: 3155.0 s
# [2,   700] loss: 0.000
# elapsed time: 3250.6 s
# [2,   800] loss: 0.000
# elapsed time: 3345.6 s
# [2,   900] loss: 0.000
# elapsed time: 3440.2 s
# [2,  1000] loss: 0.000
# elapsed time: 3535.8 s
# [2,  1100] loss: 0.000
# elapsed time: 3631.8 s
# [2,  1200] loss: 0.000
# elapsed time: 3727.4 s
# [2,  1300] loss: 0.000
# elapsed time: 3822.5 s
# [2,  1400] loss: 0.000
# elapsed time: 3917.3 s
# [2,  1500] loss: 0.000
# elapsed time: 4012.8 s
# [2,  1600] loss: 0.000
# elapsed time: 4109.3 s
# [2,  1700] loss: 0.000
# elapsed time: 4204.5 s
# [2,  1800] loss: 0.000
# elapsed time: 4300.4 s
# [2,  1900] loss: 0.000
# elapsed time: 4395.9 s
# [2,  2000] loss: 0.000
# elapsed time: 4492.0 s
# [2,  2100] loss: 0.034
# elapsed time: 4588.7 s
# [2,  2200] loss: 0.044
# elapsed time: 4684.8 s
# [2,  2300] loss: 0.012
# elapsed time: 4781.6 s
# [2,  2400] loss: 0.001
# elapsed time: 4878.5 s
# [2,  2500] loss: 0.001
# elapsed time: 4975.6 s
# [2,  2600] loss: 0.000
# elapsed time: 5072.1 s
# Finished Training. Elapsed time:  5164.6560826301575

# %% [markdown]
# ### save the trained model

# %%
state_holder_path = "./state_holder2.pth"
torch.save(resnet.state_dict(), state_holder_path)

# %% [markdown]
# ### Visualize stats

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

axes[0].plot(range(len(loss_transition_holder)), loss_transition_holder, label = "loss")
axes[0].set_title("transition of loss")
axes[0].legend()

axes[1].plot(range(len(accracy_transition_holder)), accracy_transition_holder, label =  "accracy")
axes[1].set_title("transition of accuracy")
axes[1].legend()

#０個目と１個目のグラフが重ならないように調整
fig.tight_layout()

# %% [markdown]
# ### test the model

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in test_loader:
        inputs, labels = data
        labels -= 1  # なぜかinputsがImageFolderによって1,2でラベル付けされたらしい。0-indexedにする。
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = resnet(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy on the test: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy on the test: 100 %

# %% [markdown]
# ### シーン解析なので注目している物体の詳細よりおおまかな領域が欲しい。のでGradCAMを試す。
